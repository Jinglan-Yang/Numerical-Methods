# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Q2.a.

# %%
x = np.arange(2.920, 3.080, 0.001)
y = x**8-24*(x**7)+252*(x**6)-1512*(x**5)+5670*(x**4)-13608*(x**3)+20412*(x**2)-17496*x+6561
plt.plot(x, y)

# %%
# Q2.b.

# %%
x = np.arange(2.920, 3.080, 0.001)
y = (x-3)**8
plt.plot(x, y)

# %%
# Q3.a.

# %%
x=[x for x in range(1,61)]

# %%
y=[]
for i in range(60):
    if i==0:
        yValue= 1/3
    elif i==1:
        yValue=1/12
    else:
        yValue=(9/4)*y[i-1]-(1/2)*y[i-2]
    y.append(yValue)

# %%
y
# Out:
# [0.3333333333333333,
#  0.08333333333333333,
#  0.020833333333333343,
#  0.0052083333333333565,
#  0.0013020833333333807,
#  0.00032552083333342845,
#  8.138020833352365e-05,
#  2.034505208371398e-05,
#  5.0862630215946285e-06,
#  1.2715657567309247e-06,
#  3.1789144184726645e-07,
#  7.947286579088713e-08,
#  1.986822710586282e-08,
#  4.9670780927477775e-09,
#  1.24181215575109e-09,
#  3.105383040660637e-10,
#  7.780510627309835e-11,
#  1.9792337081439436e-11,
#  5.630205296689555e-12,
#  2.771793376831781e-12,
#  3.42143244952673e-12,
#  6.312326323019251e-12,
#  1.249201800202995e-11,
#  2.4950877343057763e-11,
#  4.989346502086499e-11,
#  9.978485762541735e-11,
#  1.9956919714675653e-10,
#  3.9913826476749354e-10,
#  7.982764971534822e-10,
#  1.5965529862115882e-09,
#  3.193105970399332e-09,
#  6.386211940292704e-09,
#  1.2772423880458916e-08,
#  2.554484776088621e-08,
#  5.1089695521764515e-08,
#  1.0217939104352706e-07,
#  2.043587820870536e-07,
#  4.087175641741071e-07,
#  8.174351283482141e-07,
#  1.6348702566964283e-06,
#  3.2697405133928565e-06,
#  6.539481026785713e-06,
#  1.3078962053571426e-05,
#  2.6157924107142852e-05,
#  5.2315848214285705e-05,
#  0.00010463169642857141,
#  0.00020926339285714282,
#  0.00041852678571428564,
#  0.0008370535714285713,
#  0.0016741071428571425,
#  0.003348214285714285,
#  0.00669642857142857,
#  0.01339285714285714,
#  0.02678571428571428,
#  0.05357142857142856,
#  0.10714285714285712,
#  0.21428571428571425,
#  0.4285714285714285,
#  0.857142857142857,
#  1.714285714285714]

# %%
plt.plot(x, y)

# %%
plt.semilogy(x,y)

# %%
plt.semilogx(x,y)

# %%
# Q3.b.

# %%
x=[x for x in range(1,61)]
y =[]
for i in x:
    y.append(1/3*(4**(1-i)))

# %%
plt.plot(x,y)

# %%
plt.semilogy(x,y)

# %%
plt.semilogx(x,y)
